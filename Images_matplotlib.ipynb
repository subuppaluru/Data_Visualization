# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
#Reading the image
img = mpimg.imread('Taj.JPG')
#Printing the image array
print(img)
# Out:
# [[[106 159 209]
#   [106 159 209]
#   [106 159 209]
#   ...
#   [104 158 204]
#   [105 159 205]
#   [105 159 205]]
#
#  [[106 159 209]
#   [106 159 209]
#   [106 159 209]
#   ...
#   [104 158 204]
#   [105 159 205]
#   [105 159 205]]
#
#  [[106 159 209]
#   [106 159 209]
#   [106 159 209]
#   ...
#   [104 158 204]
#   [105 159 205]
#   [105 159 205]]
#
#  ...
#
#  [[125 144  63]
#   [128 147  66]
#   [130 149  68]
#   ...
#   [132 117  62]
#   [134 119  64]
#   [134 119  64]]
#
#  [[126 145  66]
#   [129 148  69]
#   [129 148  69]
#   ...
#   [132 117  60]
#   [134 119  62]
#   [134 119  62]]
#
#  [[126 147  70]
#   [128 149  72]
#   [127 148  71]
#   ...
#   [132 117  58]
#   [136 121  62]
#   [136 121  62]]]

# %%
print(img.shape)
(853, 640, 4)
# Out:
# (683, 714, 3)
# (853, 640, 4)

# %%
#Displaying the image
imgplot = plt.imshow(img)

# %%
selected_part = img[290:680 , 10:630 , : ]
plt.imshow(selected_part)

# %%
#Add color bar
imgplot = plt.imshow(img)
plt.colorbar()

# %%
#Removing the Axes with Matplotlib
plt.axis("off")
plt.imshow(img)

# %%
#Converting a Color Image into a Grayscale Image
grayscale_img = img[:, :, 0]
plt.imshow(grayscale_img, cmap='gray')

# %%
##Saving an Image
plt.imshow(grayscale_img)

# %%
plt.imshow(grayscale_img,cmap ='hot')
plt.savefig("New_Image.png")

# %%
#Plotting Histogram of the Image Data with Matplotlib
plt.hist(img.ravel())
# Out:
# (array([ 18211.,  68910.,  89855.,  77151., 291631., 174160., 299837.,
#         300000., 136966.,   6265.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)
